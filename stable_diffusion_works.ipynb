# %%
# !pip install --upgrade git+https://github.com/huggingface/diffusers.git transformers accelerate scipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/huggingface/diffusers.git
#   Cloning https://github.com/huggingface/diffusers.git to /tmp/pip-req-build-4mlcv10h
#   Running command git clone -q https://github.com/huggingface/diffusers.git /tmp/pip-req-build-4mlcv10h
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting transformers
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 5.1 MB/s
# Collecting accelerate
#   Downloading accelerate-0.15.0-py3-none-any.whl (191 kB)
#      |████████████████████████████████| 191 kB 60.8 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (1.7.3)
# Collecting scipy
#   Downloading scipy-1.9.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.8 MB)
#      |████████████████████████████████| 33.8 MB 81.9 MB/s
# Requirement already satisfied: Pillow in /usr/local/lib/python3.8/dist-packages (from diffusers==0.10.0.dev0) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from diffusers==0.10.0.dev0) (1.21.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from diffusers==0.10.0.dev0) (2022.6.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from diffusers==0.10.0.dev0) (4.13.0)
# Collecting huggingface-hub>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 68.8 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from diffusers==0.10.0.dev0) (3.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from diffusers==0.10.0.dev0) (2.23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.10.0->diffusers==0.10.0.dev0) (4.1.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.10.0->diffusers==0.10.0.dev0) (4.64.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.10.0->diffusers==0.10.0.dev0) (6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.10.0->diffusers==0.10.0.dev0) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.9->huggingface-hub>=0.10.0->diffusers==0.10.0.dev0) (3.0.9)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 59.7 MB/s
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from accelerate) (1.12.1+cu113)
# Requirement already satisfied: psutil in /usr/local/lib/python3.8/dist-packages (from accelerate) (5.4.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->diffusers==0.10.0.dev0) (3.10.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->diffusers==0.10.0.dev0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->diffusers==0.10.0.dev0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->diffusers==0.10.0.dev0) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->diffusers==0.10.0.dev0) (2.10)
# Building wheels for collected packages: diffusers
#   Building wheel for diffusers (PEP 517) ... done
#   Created wheel for diffusers: filename=diffusers-0.10.0.dev0-py3-none-any.whl size=476837 sha256=3b599974e3b19fd1f2775d3d7d73b3df9b4a9fb4cdeca064897c70dac5c94538
#   Stored in directory: /tmp/pip-ephem-wheel-cache-y5_r4dvk/wheels/28/16/cf/d8d37579fd1e7edb978252d850ec9328b055a7582ddfae3b87
# Successfully built diffusers
# Installing collected packages: tokenizers, huggingface-hub, transformers, scipy, diffusers, accelerate
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
# Successfully installed accelerate-0.15.0 diffusers-0.10.0.dev0 huggingface-hub-0.11.1 scipy-1.9.3 tokenizers-0.13.2 transformers-4.25.1

# %%
from diffusers import StableDiffusionPipeline, EulerDiscreteScheduler

# %%
model_id = "stabilityai/stable-diffusion-2"

# %%
import torch
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
# Use the Euler scheduler here instead
scheduler = EulerDiscreteScheduler.from_pretrained(model_id, subfolder="scheduler")
pipe = StableDiffusionPipeline.from_pretrained(model_id, scheduler=scheduler, revision="fp16", torch_dtype=torch.float16)
pipe = pipe.to(device)
# Out:
# Downloading:   0%|          | 0.00/345 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/511 [00:00<?, ?B/s]
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/624 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/681M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/460 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/815 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/900 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.73G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/602 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/167M [00:00<?, ?B/s]

# %%
# prompt = "a photo of an astronaut riding a horse on mars"
prompt = "packet of cookies sold by Amazon. The packet has Amazon branding."

# %%
image = pipe(prompt, height=768, width=768).images[0]
    
image.save("amazon_new.png")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
from google.colab import files

# %%
import os
to_download = os.listdir()
to_download = [f for f in to_download if f.split(".")[-1]=="png"]

# %%
for f in to_download:
  files.download(f)
